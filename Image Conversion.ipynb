# %%
import hyperspy.api as hs
import matplotlib.pyplot as plt
import numpy as np
from sklearn import cluster
from skimage.transform import rescale, resize, downscale_local_mean
import string
# Out:
# WARNING:hyperspy_gui_traitsui:The module://ipykernel.pylab.backend_inline matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
cd A:\School\Mat 397\Smeltzer STEM\Smeltzer Dm3 Photos
# Out:
# A:\School\Mat 397\Smeltzer STEM\Smeltzer Dm3 Photos

# %%
images= hs.load('***.dm3', lazy=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-dd78a69fec05> in <module>
# ----> 1 images= hs.load('***.dm3', lazy=True)
#
# A:\Anaconda\lib\site-packages\hyperspy\io.py in load(filenames, signal_type, stack, stack_axis, new_axis_name, lazy, convert_units, **kwds)
#     279             objects = [load_single_file(filename, lazy=lazy,
#     280                                         **kwds)
# --> 281                        for filename in filenames]
#     282
#     283         if len(objects) == 1:
#
# A:\Anaconda\lib\site-packages\hyperspy\io.py in <listcomp>(.0)
#     279             objects = [load_single_file(filename, lazy=lazy,
#     280                                         **kwds)
# --> 281                        for filename in filenames]
#     282
#     283         if len(objects) == 1:
#
# A:\Anaconda\lib\site-packages\hyperspy\io.py in load_single_file(filename, **kwds)
#     316     else:
#     317         reader = io_plugins[i]
# --> 318         return load_with_reader(filename=filename, reader=reader, **kwds)
#     319
#     320
#
# A:\Anaconda\lib\site-packages\hyperspy\io.py in load_with_reader(filename, reader, signal_type, convert_units, **kwds)
#     323     lazy = kwds.get('lazy', False)
#     324     file_data_list = reader.file_reader(filename,
# --> 325                                         **kwds)
#     326     objects = []
#     327
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in file_reader(filename, record_by, order, lazy, optimize)
#    1026     with open(filename, "rb") as f:
#    1027         dm = DigitalMicrographReader(f)
# -> 1028         dm.parse_file()
#    1029         images = [ImageObject(imdict, f, order=order, record_by=record_by)
#    1030                   for imdict in dm.get_image_dictionaries()]
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_file(self)
#      86             number_of_root_tags,
#      87             group_name="root",
# ---> 88             group_dict=self.tags_dict)
#      89
#      90     def parse_header(self):
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_tags(self, ntags, group_name, group_dict)
#     215                     ntags=ntags,
#     216                     group_name=tag_name,
# --> 217                     group_dict=group_dict[tag_name])
#     218             else:
#     219                 _logger.debug('File address:', self.f.tell())
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_tags(self, ntags, group_name, group_dict)
#     215                     ntags=ntags,
#     216                     group_name=tag_name,
# --> 217                     group_dict=group_dict[tag_name])
#     218             else:
#     219                 _logger.debug('File address:', self.f.tell())
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_tags(self, ntags, group_name, group_dict)
#     215                     ntags=ntags,
#     216                     group_name=tag_name,
# --> 217                     group_dict=group_dict[tag_name])
#     218             else:
#     219                 _logger.debug('File address:', self.f.tell())
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_tags(self, ntags, group_name, group_dict)
#     114         for tag in range(ntags):
#     115             _logger.debug('Reading tag name at address: %s', self.f.tell())
# --> 116             tag_header = self.parse_tag_header()
#     117             tag_name = tag_header['tag_name']
#     118
#
# A:\Anaconda\lib\site-packages\hyperspy\io_plugins\digital_micrograph.py in parse_tag_header(self)
#     451
#     452     def parse_tag_header(self):
# --> 453         tag_id = iou.read_byte(self.f, "big")
#     454         tag_name_length = iou.read_short(self.f, "big")
#     455         tag_name = self.read_string(tag_name_length)
#
# A:\Anaconda\lib\site-packages\hyperspy\misc\io\utils_readfile.py in read_byte(f, endian)
#     238         elif endian == 'little':
#     239             s = L_byte
# --> 240         return s.unpack(data)[0]
#     241
#     242
#
# error: unpack requires a buffer of 1 bytes

# %%
images
# Out:
# [<LazySignal2D, title: 001 HAADF 3mmbf 6C 40um 150kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 001 HAADF 6C 8cm 6mm 40CL 20kX, dimensions: (|512, 512)>,
#  <LazySignal2D, title: 016 BF 6C 40CL 6mmbf alpha3 150kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 6C 40CL 6mmbf alpha3 250kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 6C 40CL 8mm 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 6C 40CL 12MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 6C 40CL BF3mm 8cm 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 6C 40umCL 8cm 6mm 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 7C 50CL alpha3 8cm 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 12Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 15Mx 6C 8cm CL40um Alpha3 X -5.8  Y 7.4, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 40CL 6C 6mmBF 8cm 1.2MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 60kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 200kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 200kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF 250kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 016 BF CL40um 8cm 3mm 6C 6MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 016_BF_2Mx_4C_40CL_alpha3, dimensions: (|512, 512)>,
#  <LazySignal2D, title: 017 HAADF 1.5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 3mmbf 6C 50um 600kx fe seg maybe, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 8cm CL40um Alpha3 300kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 6mm 8cm 1.2MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 6mmbf  8cm  ALPHA3 200kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 6mmbf alpha1 8cm 400kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 6mmbf alpha3 250kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 8MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0017 HAADF 6C 40CL 8cm 80kx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL 8mm 6MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 017 HAADF 6C 40CL BF3mm 8cm 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 7C 50CL alpha3 8cm 4MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 12Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 25Kx 6C 8cm CL40um Alpha3 X -5.8  Y 7.4, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0017 HAADF 40CL 6mm 8cm 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 HAADF 500kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 017 BF CL40um 8cm 3mm 6C 500kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0017 HAADF bf3mm 6C 40um alpha3 10Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 3mmbf 6C 50um 600kx fe seg maybe, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 8cm 6mm 40CL 5MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 018 BF 6C 8cm CL40um Alpha3 300kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 40CL 6mm 8cm 1.2MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 018 BF 6C 40CL 6mmbf  8cm  ALPHA3 200kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 40CL 6mmbf alpha3 250kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0018 BF 6C 40CL 8cm 80kx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 40CL 8mm 6MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 018 BF 6C 40CL BF3mm 8cm 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 6C 40umCL 8cm 6mm 12MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 018 BF 7C 50CL alpha3 8cm 4MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 12Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 25Kx 6C 8cm CL40um Alpha3 X -5.8  Y 7.4, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 40CL 6C 6mmBF 8cm 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 200kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 250kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018 BF 500kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0018 BF bf3mm 6C 40um alpha3 10Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 018_BF_60kx_6C_40CL_alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 1Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 8cm CL40um Alpha3 80kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 6mm 8cm 3MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 6mmbf  8cm  ALPHA3 200kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 6mmbf alpha1 8cm 600kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 6mmbf alpha3 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 6mmbf alpha3 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0019 HAADF 6C 40CL 8cm 8Mx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 8mm 500kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 6C 40CL 500kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 7C 50CL alpha3 8cm 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 40CL 6C 6mmBF 8cm 3MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0019 HAADF 40CL 6mm 8cm 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF 600kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 019 HAADF CL40um 8cm 3mm 6C 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0019 HAADF bf3mm 6C 40um alpha3 10Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 1Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 8cm 6mm 40CL 600kX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 020 BF 6C 8cm CL40um Alpha3 80kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL 6mmbf  8cm 10MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL 6mmbf alpha3 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL 6mmbf alpha3 100kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL 6mmbf alpha3 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL 8mm 500kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 6C 40CL BF3mm 8cm 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 7C 50CL alpha3 8cm 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 40CL 6C 6mmBF 8cm 3MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0020 BF 40CL 6mm 8cm 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 100kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 500kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF 600kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 020 BF CL40um 8cm 3mm 6C 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0020 BF bf3mm 6C 40um alpha3 10Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 1Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 4Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 8cm 6mm 40CL 2.5MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 021 HAADF 6C 8cm CL40um Alpha3 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 4MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mm 8cm 2MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf  8cm 8MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf  8cm  ALPHA3 200kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf alpha1 8cm 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf alpha3 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 6mmbf alpha3 400kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0021 HAADF 6C 40CL 8cm 100kx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL 8mm 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40CL BF3mm 8cm 150kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 6C 40umCL 8cm 6mm 3MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 7C 50CL alpha3 8cm 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 40CL 6C 6mmBF 8cm 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0021 HAADF 40CL 6mm 8cm 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 200kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 400kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF 600kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021 HAADF CL40um 8cm 3mm 6C 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0021 HAADF bf3mm 6C 40um alpha3 5Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 021_HAADF_100kx_6C_40CL_alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 1Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 4Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 8cm 6mm 40CL 2.5MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 022 BF 6C 8cm CL40um Alpha3 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 4MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 6mmbf  8cm  ALPHA3 200kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 6mmbf alpha1 8cm 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 6mmbf alpha3 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40CL 6mmbf alpha3 400kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0022 BF 6C 40CL 8cm 100kx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 6C 40umCL 8cm 6mm 3MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 7C 50CL alpha3 8cm 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 BF 600kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 1Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 2Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 8cm 6mm 40CL 4MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 023 HAADF 6C 8cm CL40um Alpha3 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf  8cm 10MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf  8cm  ALPHA3 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf alpha1 8cm 1.5MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf alpha3 2MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf alpha3 15MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40CL 6mmbf alpha3 500kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 022 HAADF 6C 40CL 8mm 1MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 6C 40umCL 8cm 6mm 10MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 023 HAADF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 200kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 300kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF 500kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 023 HAADF CL40um 8cm 3mm 6C 3MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 0023 HAADF bf3mm 6C 40um alpha3 20Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 1Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 2Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 8cm 6mm 40CL 4MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 024 BF 6C 8cm CL40um Alpha3 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 40CL 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 40CL 6mmbf  8cm 10MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 40CL 6mmbf  8cm  ALPHA3 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 40CL 6mmbf alpha1 8cm 1.5MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 6C 40CL 6mmbf alpha3 2MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 40CL 6C 6mmBF 8cm 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0024 BF 40CL 6mm 8cm 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 200kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 300kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF 500kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 BF CL40um 8cm 3mm 6C 3MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 0024 BF bf3mm 6C 40um alpha3 20Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 024 HAADF 6C 40umCL 8cm 6mm 10MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 025 HAADF 4Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 8cm CL40um Alpha3 1Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40CL 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40CL 6mmbf alpha1 8cm 800kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40CL 6mmbf alpha3 3MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40CL 6mmbf alpha3 12MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40CL 6mmbf alpha3 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0025 HAADF 6C 40CL 8cm 6Mx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 6C 40umCL 8cm 6mm 12MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 40CL 6C 6mmBF 8cm 2.5MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0025 HAADF 40CL 6mm 8cm 100kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 150kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF 600kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025 HAADF CL40um 8cm 3mm 6C 10MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 0025 HAADF bf3mm 6C 40um alpha3 10Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 025_HAADF_200kx_6C_40CL_alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 3Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40CL 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40CL 6mm 8cm 800kX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 026 BF 6C 40CL 6mmbf  8cm  ALPHA3 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40CL 6mmbf alpha3 12MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0026 BF 6C 40CL 8cm 6Mx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40CL 8mm 600kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40CL BF3mm 8cm 800kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 6C 40umCL 8cm 6mm 12MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 40CL 6C 6mmBF 8cm 2.5MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0026 BF 40CL 6mm 8cm 100kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 150kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 400Kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 600kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF 600kx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 026 BF CL40um 8cm 3mm 6C 10MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 027 HAADF 1Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 2.5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 6C 8cm 6mm 40CL 3MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 027 HAADF 6C 40CL 6mmbf  8cm 8MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 6C 40CL 6mmbf alpha3 4MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 6C 40CL 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 40CL 6mm 8cm 200kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0027 HAADF 40CL 6mm 8cm 250kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 027 HAADF 400kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0027 HAADF bf3mm 6C 40um alpha3 5Mx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 1.5Mx 6C 10cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 5Mx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 8cm 6mm 40CL 3MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 6mm 8cm 1.5MX, dimensions: (|2048, 2048)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 6mmbf  8cm 8MX ALPHA3, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 6mmbf  8cm  ALPHA3 300kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 6mmbf alpha1 8cm 120kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 6mmbf alpha3 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0028 BF 6C 40CL 8cm 4Mx 6mm BFap, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40CL 20MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40CL BF3mm 8cm 400kx, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 6C 40umCL 8cm 6mm 10MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 40CL 6C 6mmBF 8cm 6MX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 0028 BF 40CL 6mm 8cm 250kX, dimensions: (|1024, 1024)>,
#  <LazySignal2D, title: 028 BF 400kx 6C 8cm CL40um Alpha3, dimensions: (|1024, 1024)>]

# %%
for x in range(len(images)):
    plt.imsave(str(x+1000)+'image.png',images[x])

# %%
plt.imshow(images[0])
