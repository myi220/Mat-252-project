# %%
import hyperspy.api as hs
import matplotlib.pyplot as plt
import numpy as np
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean

# %%
unsized_images = hs.load('**TEST/*.dm3')
print(unsized_images)
# Out:
# [<Signal2D, title: 5 HAADF 4C 20K GB1, dimensions: (|1024, 1024)>, <Signal2D, title: 08 BF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 10 BF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 13 HAADF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 15 BF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 15 HAADF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 16 HAADF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 17 BF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 17 HAADF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 18 HAADF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 20 ABF Eu-Spinel 1600C 111 Fracture 6C 8CM, dimensions: (|512, 512)>, <Signal2D, title: 20 HAADF Eu-Spinel 1600C 11
# ...

# %%
resized_images = []
for unsized_images in unsized_images:
    temp = resize(unsized_images.data, (256, 256))
    resized_images.append(temp)

# %%
a = resize(unsized_images[0].data, (256, 256))

# %%
plt.imshow(a)

# %%
b = []

# %%
b.append(a)

# %%
resized_images
# Out:
# [array([[1.36310700e-06, 1.41101191e-06, 1.43056968e-06, ...,
#          3.03392881e-05, 3.03051784e-05, 2.91364268e-05],
#         [1.03638740e-06, 1.40926568e-06, 1.44995283e-06, ...,
#          3.06799775e-05, 3.04488349e-05, 2.97156512e-05],
#         [1.17911259e-06, 1.68761471e-06, 1.90903666e-06, ...,
#          3.05110589e-05, 3.00128013e-05, 3.10631585e-05],
#         ...,
#         [4.03390732e-05, 3.90801579e-05, 3.99465207e-05, ...,
#          6.70994632e-06, 6.25889516e-06, 5.44294017e-06],
#         [3.94796371e-05, 3.96781252e-05, 4.03355225e-05, ...,
#          6.60953811e-06, 6.12711301e-06, 5.56139276e-06],
#         [3.81877180e-05, 4.07565385e-05, 4.27117921e-05, ...,
#          6.68299617e-06, 6.25156099e-06, 6.48805872e-06]]),
#  array([[0.00087365, 0.00086783, 0.00086534, ..., 0.00069834, 0.00070305,
#          0.00069859],
#         [0.00087466, 0.00086306, 0.00087414, ..., 0.0007036 , 0.00070282,
#          0.00070008],
# ...

# %%
temp = resize(unsized_images[0].data, (256, 256))

# %%
temp
# Out:
# array([[1.36310700e-06, 1.41101191e-06, 1.43056968e-06, ...,
#         3.03392881e-05, 3.03051784e-05, 2.91364268e-05],
#        [1.03638740e-06, 1.40926568e-06, 1.44995283e-06, ...,
#         3.06799775e-05, 3.04488349e-05, 2.97156512e-05],
#        [1.17911259e-06, 1.68761471e-06, 1.90903666e-06, ...,
#         3.05110589e-05, 3.00128013e-05, 3.10631585e-05],
#        ...,
#        [4.03390732e-05, 3.90801579e-05, 3.99465207e-05, ...,
#         6.70994632e-06, 6.25889516e-06, 5.44294017e-06],
#        [3.94796371e-05, 3.96781252e-05, 4.03355225e-05, ...,
#         6.60953811e-06, 6.12711301e-06, 5.56139276e-06],
#        [3.81877180e-05, 4.07565385e-05, 4.27117921e-05, ...,
#         6.68299617e-06, 6.25156099e-06, 6.48805872e-06]])

# %%
plt.imshow(unsized_images[13].data[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-373a7624d51c> in <module>
# ----> 1 plt.imshow(unsized_images[13].data[2])
#
# TypeError: 'Signal2D' object is not subscriptable
