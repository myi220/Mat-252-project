# %%
import hyperspy.api as hs
import matplotlib.pyplot as plt
import numpy as np
from sklearn import cluster
from skimage.transform import rescale, resize, downscale_local_mean

# %%
unsized_images = hs.load('**TEST/*.dm3')
#print(unsized_images)
len(unsized_images)
# Out:
# 137

# %%
resized_images = []
for unsized_images in unsized_images:
    temp = resize(unsized_images.data, (224, 224))
    resized_images.append(temp)

# %%
resized_images[0]
plt.imshow(resized_images[120])

# %%
len(resized_images)
# Out:
# 137

# %%
w=10
h=10
fig = plt.igure(figsize=(8,8))
columns = 5
rows = 5
for i in reange(1, columns*rows +1):
    img
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-894bc393d703> in <module>
#       1 k_means = cluster.KMeans(n_clusters=56, n_jobs=-1)
# ----> 2 k_means.fit(resized_images.reshape((resized_images.shape[0], -1)))
#       3
#       4 # print top 10 image which label by 25
#       5 for resized_images in resized_images[np.where(k_means.labels_==25)[0][:10]]:
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
plt.imshow(unsized_images[45])

# %%
unsized_images[45]
# Out:
# <Signal2D, title: 5 HAADF 4C 20K GB1, dimensions: (|1024, 1024)>
